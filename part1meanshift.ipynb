# %%
from sklearn.cluster import MeanShift
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
# Create synthetic data
X, Y = make_blobs(n_samples=100, centers=3, random_state=42, cluster_std = 0.9)

# %%
# Create synthetic data
X, Y = make_blobs(n_samples=100, centers=3, random_state=42, cluster_std = 0.9)

# %%
# Apply Mean Shift clustering
mean_shift = MeanShift()
mean_shift.fit(X)
# Out:
# MeanShift()

# %%
# Visualize the results
plt.scatter(X[:, 0], X[:, 1], c=mean_shift.labels_, cmap='viridis', marker='o')
plt.scatter(mean_shift.cluster_centers_[:, 0], mean_shift.cluster_centers_[:, 1], 
            c='red', marker='x', s=200, linewidths=3, label='Cluster Centers')
plt.title('Mean Shift Clustering')
plt.legend()
plt.show()

# %%
from sklearn.cluster import MeanShift, KMeans

# %%
# Create synthetic data
X, Y= make_blobs(n_samples=300, centers=3, random_state=42)

# %%
# Apply Mean Shift clustering
mean_shift = MeanShift()
mean_shift.fit(X)
# Out:
# MeanShift()

# %%
# Apply K-Means clustering for comparison
kmeans = KMeans(n_clusters=3, n_init=4)
kmeans.fit(X)
# Out:
# C:\Users\Student\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# KMeans(n_clusters=3, n_init=4)

# %%
# Visualize the results
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=mean_shift.labels_, cmap='viridis', marker='o')
plt.scatter(mean_shift.cluster_centers_[:, 0], mean_shift.cluster_centers_[:, 1], 
       c='red', marker='x', s=200, linewidths=3, label='Cluster Centers')
plt.title('Mean Shift Clustering')
 
plt.subplot(1, 2, 2)
plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_, cmap='viridis', marker='o')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 
            c='red', marker='x', s=200, linewidths=3, label='Cluster Centers')
plt.title('K-Means Clustering')
 
plt.show()
